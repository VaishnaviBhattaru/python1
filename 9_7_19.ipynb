# %%
# basic list operations
lst1= [1,9,6,18,2]
print(len(lst1)) # length of the list
print(lst1*2) # repetition
print (9 in lst1) # true or false
print(15 in lst1) # true or false
for x in range(len(lst1)):
   print(lst1[x], end = " ")
# Out:
# 5
# [1, 9, 6, 18, 2, 1, 9, 6, 18, 2]
# True
# False
# 1 9 6 18 2

# %%
# functions of the list
lst1
print(min(lst1)) # min item/element of list
print(max(lst1)) # max element of list
print(sum(lst1)) # sum of all elements of list
print(sum(lst1)//len(lst1)) # Average of list elements
print(sum(lst1[1::2])/len(lst1[1::2])) # average of all
# Out:
# 1
# 18
# 36
# 7
# 13.5

# %%
lst1
lst1.append(24)# adding a new element at the end of the list
lst1
lst1.insert(2,56)#addimg an element at perticular index
lst1
lst1.count(10)#return a value how many times the object repeated
lst1.sort()# it sort the list in asc order
lst1
lst1.pop()#remove an element from end
lst1
lst1.pop(1)
lst1
lst2=[123,45,23]
lst1.extend(lst2)# merge the list2 into list1
lst1
# Out:
# [1, 6, 9, 18, 24, 123, 45, 23]

# %%
li=[1,9,8,2,6,3]
print(li[-1:0:-2])
print(li[-1::-3])
# Out:
# [3, 2, 9]
# [3, 8]

# %%
li.sort()
li
# Out:
# [1, 2, 3, 6, 8, 9]

# %%
li.count(6)
# Out:
# 1

# %%
# function to find the 2nd largest
l=[1,45,3,13,24,5]
l.sort()
print(l[-2])
# Out:
# 24

# %%
# function to find the 2nd largest
def anylarge(x,n) :
  x.sort()
  print(x[-n])
anylarge([2,37,4,67,23],3)
# Out:
# 23

# %%
#convert digits into nos
y=[1,4,5,6,9]
z=0
for x in range (len(y)):
  z=z*10+y[x]
print(z)
# Out:
# 14569

# %%
y=[1,4,5,6,9]
z=0
for x in range (len(y)):
  if y[x]%2 == 0:
    z=z*10+y[x]
print(z)
# Out:
# 46

# %%
y=[1,4,5,6,9]
z=[]
for x in range (len(y)):
  if y[x]%2 == 0:
    z.append(y[x]**2)
  else:
    z.append(y[x])
z
# Out:
# [1, 16, 5, 36, 9]

# %%
v=[15,19,12,16,4]
a=[]
a.append(v[0])

for x in range (1,len(v)):
  a.append(v[x]+v[x-1])
a
# Out:
# [15, 34, 31, 28, 20]
