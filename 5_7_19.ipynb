# %%
print("hello gitam")
# Out:
# hello gitam

# %%
print("hyderabad","|||",end=" ")
print("gitam hyd",end=" ||| ")
print("GITAM")
# Out:
# hyderabad ||| gitam hyd ||| GITAM

# %% [markdown]
# Google Site -- [1]:http://www.google.com

# %% [markdown]
# ASSIGNMENT

# %%
N1=100#single variable assignment
a=b=c=20#multivariable assignment
x,y,z=10,20,30
print(N1)
print(a,b,c)
print(x,y,z)
print(type(a))
# Out:
# 100
# 20 20 20
# 10 20 30
# <class 'int'>

# %%
a=10
s1="phyton"
s2='p'
s3=10.3
print(a,s1,s2,s3)
print(type(a),type(s1),type(s2),type(s3))
# Out:
# 10 phyton p 10.3
# <class 'int'> <class 'str'> <class 'str'> <class 'float'>
